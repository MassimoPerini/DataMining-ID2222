# %%
import itertools
candidate_set = {}
singletons = {}
itemsets = []
threshold = 50
path = "/Users/massimo/OneDrive - Politecnico di Milano/OSX/Documents/KTH/datamining/data.dat"
inFile = open(path, 'r')
lines = [line.strip('\n').strip() for line in inFile]
sets = [frozenset(i.split(" ")) for i in lines]

#generating singletons
for line in sets:
    for item in line:
            #item = set(item)
        if item in candidate_set:
            candidate_set[item]+=1
        else:
            candidate_set[item] = 1
#checking threshold
itemsets = []
itemset = {}
for key, value in candidate_set.items():
    if value >= threshold:
        singletons[key] = value
        itemset[frozenset([key])] = value
        
itemsets+=[itemset]        
current_len = 2

while len(itemset) > 0:
    print("itemset size: ", len(itemset))
    candidate_set = {}
    print(current_len)
    #generating candidates
    print("generating...")
    #generating (previous items set, singleton) tuple
    for entry in ((x,y) for x in itemset.keys() for y in singletons.keys()):
        if entry[1] in entry[0]:#avoid the singleton is in item set (otherwise the set won't contain current_len elements)
            continue
        passed = True
        for i in range (2, current_len):#checking the frequency of subsets
            for comb in itertools.combinations(entry[0], i-1):#test subsets = subsets of the previous items set (from 2 length subsets to current_len-1). E.g. generating 4 elements subsets: len-1 + new item, len-2 + new item 
                test = frozenset(comb).union(frozenset([entry[1]]))
                if test not in itemsets[i-1]:
                    passed = False
                    break
            if not passed:
                break
        if not passed:
            continue
        candidate_set[entry[0].union(frozenset([entry[1]]))] = 0
    itemset = {}
    #new scan
    if len(candidate_set) == 0:
        break
    print("scanning... ", len(candidate_set), "elements")
    #with open(path) as f:
    i=0
    if current_len <= 4:
        candidates_list = set(candidate_set.keys())
        new_sets = []
        for line in sets:
            comb_list = set(frozenset(i) for i in itertools.combinations(line, current_len))
            common = (candidates_list & comb_list)
            for el in common:
                #print(common)
                candidate_set[el]+=1
            if len(common) > 0:
                new_sets+=[line]
        print("keeping ", len(new_sets)," elements instead of ", len(sets))
        sets = new_sets
    else:
        new_sets = []
        for line in sets:
            keep = False
            for candidate in candidate_set.keys():
                if candidate.issubset(line):
                    candidate_set[candidate]+=1
                    keep = True
            if keep:
                new_sets+=[line]
        print("keeping ", len(new_sets)," elements instead of ", len(sets))
        sets = new_sets

    for key, value in candidate_set.items():
        if value >= threshold:
            itemset[key] = value
    if len(itemset) > 0:
        itemsets+=[itemset]
    #print(itemsets)
    current_len+=1
print(itemsets[-1])
#print(singletons)
# Out:
# itemset size:  839
# 2
# generating...
# scanning...  351541 elements
# keeping  99871  elements instead of  100000
# itemset size:  19694
# 3
# generating...
# scanning...  378101 elements
# keeping  98615  elements instead of  99871
# itemset size:  11606
# 4
# generating...
# scanning...  9780 elements
# keeping  87078  elements instead of  98615
# itemset size:  9659
# 5
# generating...
# scanning...  6364 elements
# keeping  60971  elements instead of  87078
# itemset size:  6327
# 6
# generating...
# scanning...  3344 elements
# keeping  33506  elements instead of  60971
# itemset size:  3329
# 7
# generating...
# scanning...  1416 elements
# keeping  14302  elements instead of  33506
# itemset size:  1409
# 8
# generating...
# scanning...  440 elements
# keeping  5027  elements instead of  14302
# itemset size:  437
# 9
# generating...
# scanning...  80 elements
# keeping  1593  elements instead of  5027
# itemset size:  80
# 10
# generating...
# scanning...  5 elements
# keeping  609  elements instead of  1593
# itemset size:  5
# 11
# generating...
# {frozenset({'158', '561', '998', '193', '214', '126', '682', '843', '332', '833'}): 72, frozenset({'403', '205', '950', '207', '461', '529', '829', '285', '75', '896'}): 190, frozenset({'778', '893', '865', '381', '116', '706', '632', '523', '777', '492'}): 83, frozenset({'71', '438', '684', '108', '486', '75', '958', '8', '242', '766'}): 187, frozenset({'196', '147', '975', '464', '922', '269', '823', '42', '515', '820'}): 77}

# %%
sets[0]
# Out:
# frozenset({'164',
#            '240',
#            '25',
#            '274',
#            '328',
#            '368',
#            '448',
#            '52',
#            '538',
#            '561',
#            '630',
#            '687',
#            '730',
#            '775',
#            '825',
#            '834'})
